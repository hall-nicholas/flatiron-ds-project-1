# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import sqlite3

# %matplotlib inline

# %%
# Read relevant tables into pandas dataframe
# IMDB database
# ***IMPORTANT*** Make sure to unzip the "im.db.zip" file into "im.db"
con = sqlite3.connect('../data/im.db') 
cursor = con.cursor()
imdb_schema_df = pd.read_sql('''
SELECT 
    *
FROM
    sqlite_master
''', con)

# %%
movie_basics_df = pd.read_sql('''
SELECT 
    *
FROM
    movie_basics
''', con)

movie_basics_df
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                  None
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %%
movie_ratings_df = pd.read_sql('''
SELECT 
    *
FROM
    movie_ratings
''', con)

movie_ratings_df
# Out:
#          movie_id  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
# The Numbers movie information table
tn_movies_df = pd.read_csv('../data/tn.movie_budgets.csv.gz')

tn_movies_df
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...                ...            ...             ...
# 5777            $7,000             $0              $0
# 5778            $6,000        $48,482        $240,495
# 5779            $5,000         $1,338          $1,338
# 5780            $1,400             $0              $0
# 5781            $1,100       $181,041        $181,041
#
# [5782 rows x 6 columns]

# %%
# TheMovieDB movie information table
tmdb_movies_df = pd.read_csv('../data/tmdb.movies.csv.gz')

tmdb_movies_df
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 26512                         Laboratory Conditions       0.600   2018-10-13
# 26513                               _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                                  The Last One       0.600   2018-10-01
# 26515                                  Trailer Made       0.600   2018-06-22
# 26516                                    The Church       0.600   2018-10-05
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 26512                         Laboratory Conditions           0.0           1
# 26513                               _EXHIBIT_84xxx_           0.0           1
# 26514                                  The Last One           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26516                                    The Church           0.0           1
#
# [26517 rows x 10 columns]

# %%
# # Merge the following pandas dataframes together
#   1. movie_basics_df (from IMDB database)
#   2. movie_ratings_df (from IMDB database)
#   3. tn_movies_df (from The Numbers database)
#   4. tmdb_movies_df (from The Movie database)

movie_basics_ratings_df = pd.read_sql('''
SELECT
    *
FROM 
    movie_basics
    LEFT JOIN movie_ratings
        ON movie_basics.movie_id = movie_ratings.movie_id
''', con)

movie_basics_ratings_df
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres   movie_id  averagerating  \
# 0                 175.0    Action,Crime,Drama  tt0063540            7.0
# 1                 114.0       Biography,Drama  tt0066787            7.2
# 2                 122.0                 Drama  tt0069049            6.9
# 3                   NaN          Comedy,Drama  tt0069204            6.1
# 4                  80.0  Comedy,Drama,Fantasy  tt0100275            6.5
# ...                 ...                   ...        ...            ...
# 146139            123.0                 Drama       None            NaN
# 146140              NaN           Documentary       None            NaN
# 146141              NaN                Comedy       None            NaN
# 146142            116.0                  None       None            NaN
# 146143              NaN           Documentary       None            NaN
#
#         numvotes
# 0           77.0
# 1           43.0
# 2         4517.0
# 3           13.0
# 4          119.0
# ...          ...
# 146139       NaN
# 146140       NaN
# 146141       NaN
# 146142       NaN
# 146143       NaN
#
# [146144 rows x 9 columns]

# %%
movie_basics_ratings_tmdb_df = movie_basics_ratings_df.merge(tmdb_movies_df,
                                                             left_on='primary_title',
                                                             right_on='title',
                                                             how='inner')
movie_basics_ratings_tmdb_df
# Out:
#         movie_id                              primary_title  \
# 0      tt0069049                 The Other Side of the Wind
# 1      tt0112502                                    Bigfoot
# 2      tt4503112                                    Bigfoot
# 3      tt9181914                                    Bigfoot
# 4      tt0192528                              Heaven & Hell
# ...          ...                                        ...
# 23607  tt9678886                                    Vacancy
# 23608  tt9777830  John Leguizamo's Latin History for Morons
# 23609  tt9814730                                  The Flare
# 23610  tt9862978                                      Terra
# 23611  tt9869514                               Wake Up Call
#
#                                 original_title_x  start_year  runtime_minutes  \
# 0                     The Other Side of the Wind        2018            122.0
# 1                                        Bigfoot        2017              NaN
# 2                                        Bigfoot        2018              NaN
# 3                                        Bigfoot        2018             86.0
# 4                                 Reverse Heaven        2018            104.0
# ...                                          ...         ...              ...
# 23607                                    Vacancy        2018             81.0
# 23608  John Leguizamo's Latin History for Morons        2018              NaN
# 23609                                  The Flare        2017             63.0
# 23610                                      Terra        2018             60.0
# 23611                               Wake Up Call        2017              NaN
#
#                  genres   movie_id  averagerating  numvotes  Unnamed: 0  \
# 0                 Drama  tt0069049            6.9    4517.0       24185
# 1       Horror,Thriller  tt0112502            4.1      32.0        5872
# 2         Action,Horror  tt4503112            4.6       9.0        5872
# 3      Animation,Family  tt9181914            2.5      55.0        5872
# 4                 Drama  tt0192528            4.0      72.0       26332
# ...                 ...        ...            ...       ...         ...
# 23607       Documentary       None            NaN       NaN       22942
# 23608            Comedy  tt9777830            7.2     105.0       24840
# 23609             Sport       None            NaN       NaN       23218
# 23610       Documentary       None            NaN       NaN       25626
# 23611            Action       None            NaN       NaN       13030
#
#            genre_ids      id original_language  \
# 0           [35, 18]  299782                en
# 1      [27, 878, 12]  117856                en
# 2      [27, 878, 12]  117856                en
# 3      [27, 878, 12]  117856                en
# 4               [18]  567662                en
# ...              ...     ...               ...
# 23607       [35, 27]  475066                en
# 23608           [35]  557606                en
# 23609             []  469698                en
# 23610           [27]  536235                en
# 23611           [16]  544776                en
#
#                                 original_title_y  popularity release_date  \
# 0                     The Other Side of the Wind       9.800   2018-11-02
# 1                                        Bigfoot       2.813   2012-06-30
# 2                                        Bigfoot       2.813   2012-06-30
# 3                                        Bigfoot       2.813   2012-06-30
# 4                                  Heaven & Hell       0.600   2018-11-06
# ...                                          ...         ...          ...
# 23607                                    Vacancy       0.649   2017-10-27
# 23608  John Leguizamo's Latin History for Morons       4.304   2018-11-05
# 23609                                  The Flare       0.600   2017-07-11
# 23610                                      Terra       1.767   2018-04-24
# 23611                               Wake Up Call       0.688   2014-06-07
#
#                                            title  vote_average  vote_count
# 0                     The Other Side of the Wind           7.0          64
# 1                                        Bigfoot           2.9          26
# 2                                        Bigfoot           2.9          26
# 3                                        Bigfoot           2.9          26
# 4                                  Heaven & Hell           7.5           2
# ...                                          ...           ...         ...
# 23607                                    Vacancy           9.0           1
# 23608  John Leguizamo's Latin History for Morons           7.3          13
# 23609                                  The Flare           9.0           1
# 23610                                      Terra           5.0           1
# 23611                               Wake Up Call           6.2           3
#
# [23612 rows x 19 columns]

# %%
movie_basics_ratings_tmdb_tn_df = movie_basics_ratings_tmdb_df.merge(tn_movies_df,
                                                                     left_on='title',
                                                                     right_on='movie',
                                                                     how='inner')

movie_basics_ratings_tmdb_tn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4550 entries, 0 to 4549
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   movie_id           4550 non-null   object
#  1   primary_title      4550 non-null   object
#  2   original_title_x   4549 non-null   object
#  3   start_year         4550 non-null   int64
#  4   runtime_minutes    4088 non-null   float64
#  5   genres             4474 non-null   object
#  6   movie_id           3361 non-null   object
#  7   averagerating      3361 non-null   float64
#  8   numvotes           3361 non-null   float64
#  9   Unnamed: 0         4550 non-null   int64
#  10  genre_ids          4550 non-null   object
#  11  id_x               4550 non-null   int64
#  12  original_language  4550 non-null   object
#  13  original_title_y   4550 non-null   object
#  14  popularity         4550 non-null   float64
#  15  release_date_x     4550 non-null   object
#  16  title              4550 non-null   object
#  17  vote_average       4550 non-null   float64
#  18  vote_count         4550 non-null   int64
#  19  id_y               4550 non-null   int64
#  20  release_date_y     4550 non-null   object
#  21  movie              4550 non-null   object
#  22  production_budget  4550 non-null   object
#  23  domestic_gross     4550 non-null   object
#  24  worldwide_gross    4550 non-null   object
# dtypes: float64(5), int64(5), object(15)
# memory usage: 924.2+ KB

# %%
# Remove columns not needed for analysis
# for column in movie_basics_ratings_tmdb_tn_df.colum
columns_to_drop = ['movie_id','primary_title', 'original_title_x', 'start_year',
       'runtime_minutes', 'movie_id','Unnamed: 0', 'id_x', 'original_language',
        'original_title_y','vote_average','title','id_y','release_date_y']

movie_basics_ratings_tmdb_tn_df.drop(columns = columns_to_drop,inplace=True)

# %%
# set movie column as dataframe index
movie_basics_ratings_tmdb_tn_df.set_index('movie',inplace=True)

# %%
# Remove any non-digit character from columns production_budget, domestic_gross
# and worldwide_gross and then convert the value for these columns to integer
for column_title in ['production_budget','domestic_gross','worldwide_gross']:
    movie_basics_ratings_tmdb_tn_df[column_title].replace('[^\d]','',inplace=True,regex=True)
    movie_basics_ratings_tmdb_tn_df[column_title] = movie_basics_ratings_tmdb_tn_df[
        column_title].astype(int)

# %%
#Change 'release_date_x' to datetime object and change column name to 'release_date'
movie_basics_ratings_tmdb_tn_df['release_date_x'] = pd.to_datetime(
    movie_basics_ratings_tmdb_tn_df['release_date_x'])

movie_basics_ratings_tmdb_tn_df.rename(columns ={'release_date_x' : 'release_date'},
                                      inplace=True)

# %%
movie_basics_ratings_tmdb_tn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4550 entries, Foodfight! to The Magic Flute
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genres             4474 non-null   object
#  1   averagerating      3361 non-null   float64
#  2   numvotes           3361 non-null   float64
#  3   genre_ids          4550 non-null   object
#  4   popularity         4550 non-null   float64
#  5   release_date       4550 non-null   datetime64[ns]
#  6   vote_count         4550 non-null   int64
#  7   production_budget  4550 non-null   int64
#  8   domestic_gross     4550 non-null   int64
#  9   worldwide_gross    4550 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(4), object(2)
# memory usage: 391.0+ KB

# %%
#Replace from 'genre_ids' column the brackets '[' and ']' surrounding the numbers
movie_basics_ratings_tmdb_tn_df['genre_ids'].replace('[\[\]]','',regex=True,inplace=True)

# %%
# Create a new column called 'Assigned_genre_ids' and assign to it the first number 
# from 'genre_ids
movie_basics_ratings_tmdb_tn_df['Assigned_genre_ids'] = movie_basics_ratings_tmdb_tn_df[
    'genre_ids'].map(lambda s: s.split(',')[0])
movie_basics_ratings_tmdb_tn_df
# Out:
#                                               genres  averagerating  numvotes  \
# movie
# Foodfight!                   Action,Animation,Comedy            1.9    8248.0
# The Overnight                                   None            7.5      24.0
# The Overnight                         Comedy,Mystery            6.1   14828.0
# On the Road                  Adventure,Drama,Romance            6.1   37886.0
# On the Road                                    Drama            NaN       NaN
# ...                                              ...            ...       ...
# Dragon Ball Super: Broly  Action,Adventure,Animation            8.0   16465.0
# Teefa in Trouble                 Action,Comedy,Crime            7.4    2724.0
# Fahrenheit 11/9                          Documentary            6.7   11628.0
# The Magic Flute                                Music            NaN       NaN
# The Magic Flute                                Music            NaN       NaN
#
#                                         genre_ids  popularity release_date  \
# movie
# Foodfight!                      16, 28, 35, 10751       4.705   2013-05-07
# The Overnight                            9648, 35       6.576   2015-06-19
# The Overnight                            9648, 35       6.576   2015-06-19
# On the Road                                12, 18       8.919   2012-12-21
# On the Road                                12, 18       8.919   2012-12-21
# ...                                           ...         ...          ...
# Dragon Ball Super: Broly  28, 16, 14, 12, 35, 878       6.868   2019-01-16
# Teefa in Trouble                   18, 35, 28, 80       4.486   2018-07-20
# Fahrenheit 11/9                                99      10.003   2018-09-10
# The Magic Flute                     10402, 35, 14       0.647   2006-12-30
# The Magic Flute              14, 35, 10402, 10749       3.208   1975-11-11
#
#                           vote_count  production_budget  domestic_gross  \
# movie
# Foodfight!                        46           45000000               0
# The Overnight                    200             200000         1109808
# The Overnight                    200             200000         1109808
# On the Road                      518           25000000          720828
# On the Road                      518           25000000          720828
# ...                              ...                ...             ...
# Dragon Ball Super: Broly         721            8500000        30376755
# Teefa in Trouble                  11            1500000               0
# Fahrenheit 11/9                  142            5000000         6352306
# The Magic Flute                    2           27000000               0
# The Magic Flute                   28           27000000               0
#
#                           worldwide_gross Assigned_genre_ids
# movie
# Foodfight!                          73706                 16
# The Overnight                     1165996               9648
# The Overnight                     1165996               9648
# On the Road                       9313302                 12
# On the Road                       9313302                 12
# ...                                   ...                ...
# Dragon Ball Super: Broly        122747755                 28
# Teefa in Trouble                    98806                 18
# Fahrenheit 11/9                   6653715                 99
# The Magic Flute                         0              10402
# The Magic Flute                         0                 14
#
# [4550 rows x 11 columns]

# %%
# Drop rows where 'genre_ids' cell is empty
movie_basics_ratings_tmdb_tn_df.drop(
    movie_basics_ratings_tmdb_tn_df[
        movie_basics_ratings_tmdb_tn_df['genre_ids']== ''].index,inplace=True)

#drop rows if production_budget, domestic_gross or worldwide_gross has a value of zero
movie_basics_ratings_tmdb_tn_df.drop(movie_basics_ratings_tmdb_tn_df[
    (movie_basics_ratings_tmdb_tn_df['production_budget'] == 0) |
                 (movie_basics_ratings_tmdb_tn_df['domestic_gross'] == 0) | 
                 (movie_basics_ratings_tmdb_tn_df[
                     'production_budget'] == 0)].index,inplace=True)

#Remove rows with release date less than 2000
movie_basics_ratings_tmdb_tn_df.drop(movie_basics_ratings_tmdb_tn_df[
    movie_basics_ratings_tmdb_tn_df[
        'release_date'] < pd.to_datetime('2000')].index,inplace=True)

# Change data type for column 'Assigned_genre_ids' to integer
movie_basics_ratings_tmdb_tn_df['Assigned_genre_ids'] = movie_basics_ratings_tmdb_tn_df[
    'Assigned_genre_ids'].astype(int)

# %%
# Drop duplicated rows
movie_basics_ratings_tmdb_tn_df.drop_duplicates(inplace=True)
movie_basics_ratings_tmdb_tn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2940 entries, The Overnight to Fahrenheit 11/9
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   genres              2901 non-null   object
#  1   averagerating       2429 non-null   float64
#  2   numvotes            2429 non-null   float64
#  3   genre_ids           2940 non-null   object
#  4   popularity          2940 non-null   float64
#  5   release_date        2940 non-null   datetime64[ns]
#  6   vote_count          2940 non-null   int64
#  7   production_budget   2940 non-null   int64
#  8   domestic_gross      2940 non-null   int64
#  9   worldwide_gross     2940 non-null   int64
#  10  Assigned_genre_ids  2940 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(5), object(2)
# memory usage: 275.6+ KB

# %%
# Drop NaN rows for averagerating
movie_basics_ratings_tmdb_tn_df.dropna(subset=['averagerating'],inplace=True)
movie_basics_ratings_tmdb_tn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2429 entries, The Overnight to Fahrenheit 11/9
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   genres              2417 non-null   object
#  1   averagerating       2429 non-null   float64
#  2   numvotes            2429 non-null   float64
#  3   genre_ids           2429 non-null   object
#  4   popularity          2429 non-null   float64
#  5   release_date        2429 non-null   datetime64[ns]
#  6   vote_count          2429 non-null   int64
#  7   production_budget   2429 non-null   int64
#  8   domestic_gross      2429 non-null   int64
#  9   worldwide_gross     2429 non-null   int64
#  10  Assigned_genre_ids  2429 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(5), object(2)
# memory usage: 227.7+ KB

# %%
# Create a dictionary called 'genre_ids_dict' with key assocaited with 'Assigned_genre_ids'
# and values with writtten genre name  
genre_ids_dict = {
                28 : 'Action', 12 : 'Adventure', 16 : 'Animation', 35 : 'Comedy',
                80 : 'Crime', 99 : 'Documentary', 18: 'Drama', 10751 : 'Family',
                14 : 'Fantasy', 36 : 'History', 27 : 'Horror', 10402 : 'Music',
                9648 : 'Mystery', 10749 : 'Romance', 878 : 'Science Fiction',
                10770 : 'TV Movie', 53 : 'Thriller', 10752 : 'War', 37 : 'Western'}


# Create a column called 'Assigned_genre_name' and use the dictionary called 'genre_ids_dict
# input written genre name with the respective key
movie_basics_ratings_tmdb_tn_df['Assigned_genre_name'] = movie_basics_ratings_tmdb_tn_df[
    'Assigned_genre_ids'].map(lambda n: genre_ids_dict[n])

movie_basics_ratings_tmdb_tn_df
# Out:
#                                               genres  averagerating  numvotes  \
# movie
# The Overnight                                   None            7.5      24.0
# The Overnight                         Comedy,Mystery            6.1   14828.0
# On the Road                  Adventure,Drama,Romance            6.1   37886.0
# On the Road                                    Drama            6.0       6.0
# On the Road                                    Drama            5.7     127.0
# ...                                              ...            ...       ...
# Paul, Apostle of Christ    Adventure,Biography,Drama            6.7    5662.0
# Instant Family                          Comedy,Drama            7.4   46728.0
# Hereditary                      Drama,Horror,Mystery            7.3  151571.0
# Dragon Ball Super: Broly  Action,Adventure,Animation            8.0   16465.0
# Fahrenheit 11/9                          Documentary            6.7   11628.0
#
#                                         genre_ids  popularity release_date  \
# movie
# The Overnight                            9648, 35       6.576   2015-06-19
# The Overnight                            9648, 35       6.576   2015-06-19
# On the Road                                12, 18       8.919   2012-12-21
# On the Road                                12, 18       8.919   2012-12-21
# On the Road                                12, 18       8.919   2012-12-21
# ...                                           ...         ...          ...
# Paul, Apostle of Christ                        36      12.005   2018-03-28
# Instant Family                             35, 18      22.634   2018-11-16
# Hereditary                           27, 9648, 53      26.185   2018-06-08
# Dragon Ball Super: Broly  28, 16, 14, 12, 35, 878       6.868   2019-01-16
# Fahrenheit 11/9                                99      10.003   2018-09-10
#
#                           vote_count  production_budget  domestic_gross  \
# movie
# The Overnight                    200             200000         1109808
# The Overnight                    200             200000         1109808
# On the Road                      518           25000000          720828
# On the Road                      518           25000000          720828
# On the Road                      518           25000000          720828
# ...                              ...                ...             ...
# Paul, Apostle of Christ           98            5000000        17547999
# Instant Family                   782           48000000        67363237
# Hereditary                      2491           10000000        44069456
# Dragon Ball Super: Broly         721            8500000        30376755
# Fahrenheit 11/9                  142            5000000         6352306
#
#                           worldwide_gross  Assigned_genre_ids  \
# movie
# The Overnight                     1165996                9648
# The Overnight                     1165996                9648
# On the Road                       9313302                  12
# On the Road                       9313302                  12
# On the Road                       9313302                  12
# ...                                   ...                 ...
# Paul, Apostle of Christ          25529498                  36
# Instant Family                  119736188                  35
# Hereditary                       70133905                  27
# Dragon Ball Super: Broly        122747755                  28
# Fahrenheit 11/9                   6653715                  99
#
#                          Assigned_genre_name
# movie
# The Overnight                        Mystery
# The Overnight                        Mystery
# On the Road                        Adventure
# On the Road                        Adventure
# On the Road                        Adventure
# ...                                      ...
# Paul, Apostle of Christ              History
# Instant Family                        Comedy
# Hereditary                            Horror
# Dragon Ball Super: Broly              Action
# Fahrenheit 11/9                  Documentary
#
# [2429 rows x 12 columns]

# %%
# Create a dataframe called 'genre_ratings_df' by cpying 'movie_basics_ratings_tmdb_tn_df' 
# and rearrange columns so related columns placed close to one another

genre_ratings_df = movie_basics_ratings_tmdb_tn_df[['genres','genre_ids','Assigned_genre_ids',
                                                   'Assigned_genre_name','averagerating',
                                                    'numvotes','popularity','vote_count',
                                                    'release_date','production_budget',
                                                    'domestic_gross','worldwide_gross']].copy()

genre_ratings_df
# Out:
#                                               genres                genre_ids  \
# movie
# The Overnight                                   None                 9648, 35
# The Overnight                         Comedy,Mystery                 9648, 35
# On the Road                  Adventure,Drama,Romance                   12, 18
# On the Road                                    Drama                   12, 18
# On the Road                                    Drama                   12, 18
# ...                                              ...                      ...
# Paul, Apostle of Christ    Adventure,Biography,Drama                       36
# Instant Family                          Comedy,Drama                   35, 18
# Hereditary                      Drama,Horror,Mystery             27, 9648, 53
# Dragon Ball Super: Broly  Action,Adventure,Animation  28, 16, 14, 12, 35, 878
# Fahrenheit 11/9                          Documentary                       99
#
#                           Assigned_genre_ids Assigned_genre_name  \
# movie
# The Overnight                           9648             Mystery
# The Overnight                           9648             Mystery
# On the Road                               12           Adventure
# On the Road                               12           Adventure
# On the Road                               12           Adventure
# ...                                      ...                 ...
# Paul, Apostle of Christ                   36             History
# Instant Family                            35              Comedy
# Hereditary                                27              Horror
# Dragon Ball Super: Broly                  28              Action
# Fahrenheit 11/9                           99         Documentary
#
#                           averagerating  numvotes  popularity  vote_count  \
# movie
# The Overnight                       7.5      24.0       6.576         200
# The Overnight                       6.1   14828.0       6.576         200
# On the Road                         6.1   37886.0       8.919         518
# On the Road                         6.0       6.0       8.919         518
# On the Road                         5.7     127.0       8.919         518
# ...                                 ...       ...         ...         ...
# Paul, Apostle of Christ             6.7    5662.0      12.005          98
# Instant Family                      7.4   46728.0      22.634         782
# Hereditary                          7.3  151571.0      26.185        2491
# Dragon Ball Super: Broly            8.0   16465.0       6.868         721
# Fahrenheit 11/9                     6.7   11628.0      10.003         142
#
#                          release_date  production_budget  domestic_gross  \
# movie
# The Overnight              2015-06-19             200000         1109808
# The Overnight              2015-06-19             200000         1109808
# On the Road                2012-12-21           25000000          720828
# On the Road                2012-12-21           25000000          720828
# On the Road                2012-12-21           25000000          720828
# ...                               ...                ...             ...
# Paul, Apostle of Christ    2018-03-28            5000000        17547999
# Instant Family             2018-11-16           48000000        67363237
# Hereditary                 2018-06-08           10000000        44069456
# Dragon Ball Super: Broly   2019-01-16            8500000        30376755
# Fahrenheit 11/9            2018-09-10            5000000         6352306
#
#                           worldwide_gross
# movie
# The Overnight                     1165996
# The Overnight                     1165996
# On the Road                       9313302
# On the Road                       9313302
# On the Road                       9313302
# ...                                   ...
# Paul, Apostle of Christ          25529498
# Instant Family                  119736188
# Hereditary                       70133905
# Dragon Ball Super: Broly        122747755
# Fahrenheit 11/9                   6653715
#
# [2429 rows x 12 columns]

# %%
genre_ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2429 entries, The Overnight to Fahrenheit 11/9
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   genres               2417 non-null   object
#  1   genre_ids            2429 non-null   object
#  2   Assigned_genre_ids   2429 non-null   int64
#  3   Assigned_genre_name  2429 non-null   object
#  4   averagerating        2429 non-null   float64
#  5   numvotes             2429 non-null   float64
#  6   popularity           2429 non-null   float64
#  7   vote_count           2429 non-null   int64
#  8   release_date         2429 non-null   datetime64[ns]
#  9   production_budget    2429 non-null   int64
#  10  domestic_gross       2429 non-null   int64
#  11  worldwide_gross      2429 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(5), object(3)
# memory usage: 246.7+ KB

# %%
# The case for targeting worldwide market in order to maximize profit potential

# Create a new dataframe called 'budget_domestic_worldwide_df' from 'genre_ratings_df'
# that has three colulmns for production_budget, domestic_gross and worldwide_gross
budget_domestic_worldwide_df = genre_ratings_df[['production_budget','domestic_gross',
                                                 'worldwide_gross']].copy()


# Make boxplot for production_budget, domestic_gross and worldwide_gross all in one axes
# Remove whiskers and outliers for better visualization
fig = plt.subplots(figsize=(10,8))
colors = ['orange','blue','green']
money_overview =sns.boxplot(x='variable',y='value',
                            data=pd.melt(budget_domestic_worldwide_df),
                            whis=0,fliersize=0,palette=colors)

money_overview.set_title('Money Overview for Production and Gross Income')
money_overview.set_xlabel('')
money_overview.set_xticklabels(['Production Budget','Domestic Gross','World-wide Gross'])
money_overview.set_ylabel('Monetary Unit ($)')
money_overview.set_yscale('log')
money_overview.set_ylim(10**6,10**9);

# %%
ratings_df = genre_ratings_df[['Assigned_genre_name','averagerating','numvotes',
                              'popularity','vote_count','worldwide_gross']].copy()
ratings_df
# Out:
#                          Assigned_genre_name  averagerating  numvotes  \
# movie
# The Overnight                        Mystery            7.5      24.0
# The Overnight                        Mystery            6.1   14828.0
# On the Road                        Adventure            6.1   37886.0
# On the Road                        Adventure            6.0       6.0
# On the Road                        Adventure            5.7     127.0
# ...                                      ...            ...       ...
# Paul, Apostle of Christ              History            6.7    5662.0
# Instant Family                        Comedy            7.4   46728.0
# Hereditary                            Horror            7.3  151571.0
# Dragon Ball Super: Broly              Action            8.0   16465.0
# Fahrenheit 11/9                  Documentary            6.7   11628.0
#
#                           popularity  vote_count  worldwide_gross
# movie
# The Overnight                  6.576         200          1165996
# The Overnight                  6.576         200          1165996
# On the Road                    8.919         518          9313302
# On the Road                    8.919         518          9313302
# On the Road                    8.919         518          9313302
# ...                              ...         ...              ...
# Paul, Apostle of Christ       12.005          98         25529498
# Instant Family                22.634         782        119736188
# Hereditary                    26.185        2491         70133905
# Dragon Ball Super: Broly       6.868         721        122747755
# Fahrenheit 11/9               10.003         142          6653715
#
# [2429 rows x 6 columns]

# %%
averagerating_df = ratings_df.groupby('Assigned_genre_name').agg(
    {'averagerating' : 'median'}).sort_values(by='averagerating',ascending=False)[:10]


popularity_df = ratings_df.groupby('Assigned_genre_name').agg(
    {'popularity' : 'median'}).sort_values(by='popularity',ascending=False)[:10]

worldwide_gross_df = ratings_df.groupby('Assigned_genre_name').agg(
    {'worldwide_gross' : 'median'}).sort_values(by='worldwide_gross',ascending=False)[:10]

worldwide_gross_df
# Out:
#                      worldwide_gross
# Assigned_genre_name
# Animation                272099539.5
# TV Movie                 222383055.0
# Fantasy                  213116401.0
# Adventure                176830633.0
# Action                   135808837.0
# Family                    89895930.0
# War                       59641264.0
# Science Fiction           58978477.0
# Mystery                   58978477.0
# Horror                    47666013.0

# %%
fig,ax = plt.subplots(1,2,figsize=(12,6))
popularity_plot = sns.barplot(data=popularity_df, x = popularity_df['popularity'],
                                             y = popularity_df.index, 
                                             ax=ax[0],orient= 'h')
popularity_plot.set_title('Genre Ranking by TMDB Raking')
popularity_plot.set_ylabel('')
popularity_plot.set_xlabel('TMDB Popularity Score')

averagerating_plot = sns.barplot(data=averagerating_df, x = averagerating_df['averagerating'],
                                            y = normalized_averagerating_df.index,
                                            ax=ax[1],orient = 'h')
averagerating_plot.set_title('Genre Ranking by IMDb Ration')
averagerating_plot.set_ylabel('')
averagerating_plot.set_xlabel('IMDb Score')
fig.subplots_adjust(wspace=0.3);

# %%
# 

#fig2,ax2 = plt.subplots(figsize=(12,8))
#worldwide_gross_plot = sns.barplot(data=worldwide_gross_df, x = worldwide_gross_df[
#                                        'worldwide_gross'],y = worldwide_gross_df.index, 
#                                        orient= 'h')
